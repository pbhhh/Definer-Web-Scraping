# %%
from google.colab import drive
drive.mount('/content/drive')
from google.colab import files
uploaded = files.upload()
# Out:
# Mounted at /content/drive
#      <input type="file" id="files-5ac6b874-9d44-4944-8cd4-de46925e865b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5ac6b874-9d44-4944-8cd4-de46925e865b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# ...

# %%
import pandas as pd
import numpy as np
import requests
from bs4 import BeautifulSoup

# %%
#If we just want to try one address to see whether it is possible
url = 'https://polygonscan.com/token/0xBbba073C31bF03b8ACf7c28EF0738DeCF3695683'
# Send a GET request to the website and get the HTML content
response = requests.get(url)
html_content = response.content
# Parse the HTML content using BeautifulSoup
soup = BeautifulSoup(html_content, 'html.parser')
# Find the 'decimals' value in the HTML content
decimals_div = soup.find('div', {'id': 'ContentPlaceHolder1_trDecimals'})
if decimals_div:
    decimals_value = decimals_div.find('div', {'class': 'col-md-8'})
    if decimals_value:
        print('Decimals:', decimals_value.text.strip())
    else:
        print('<div class="col-md-8"> not found.')
else:
    print('div id="ContentPlaceHolder1_trDecimals" not found.')
# Out:
# Decimals: 18

# %%
#Then we want to try this solution to all address
tokens = pd.read_csv('tokens1.csv')
tokens
# Out:
#       name                                            address
# 0     USDT  https://polygonscan.com//token/0xc2132d05d31c9...
# 1      BNB  https://polygonscan.com//token/0x3BA4c387f786b...
# 2     USDC  https://polygonscan.com//token/0x2791bca1f2de4...
# 3     BUSD  https://polygonscan.com//token/0xdab529f40e671...
# 4    MATIC  https://polygonscan.com//token/0x0000000000000...
# ..     ...                                                ...
# 645    FET  https://polygonscan.com//token/0x7583feddbcefa...
# 646    HOT  https://polygonscan.com//token/0x0c51f415cf478...
# 647    GNO  https://polygonscan.com//token/0x5ffd62d3c3ee2...
# 648   COMP  https://polygonscan.com//token/0x8505b9d2254a7...
# 649   ANKR  https://polygonscan.com//token/0x101a023270368...
#
# [650 rows x 2 columns]

# %%
websites = tokens.address
df = pd.DataFrame(columns=['Decimals'])

# %%
#Then I try my code into all of the tokens
for i in range(0, len(websites)):
    url = websites[i]
    # Send a GET request to the website and get the HTML content
    response = requests.get(url)
    html_content = response.content

    # Parse the HTML content using BeautifulSoup
    soup = BeautifulSoup(html_content, 'html.parser')
    decimals_div = soup.find('div', {'id': 'ContentPlaceHolder1_trDecimals'})
    if decimals_div:
      decimals_value = decimals_div.find('div', {'class': 'col-md-8'})
      if decimals_value:
        print('Decimals:', decimals_value.text.strip())
      else:
        print('<div class="col-md-8"> not found.')
    else:
        print('div id="ContentPlaceHolder1_trDecimals" not found.')
# Out:
# Decimals: 6
# Decimals: 18
# Decimals: 6
# Decimals: 18
# Decimals: 18
# Decimals: 18
# Decimals: 18
# Decimals: 18
# Decimals: 18
# Decimals: 8
# Decimals: 18
# Decimals: 18
# Decimals: 18
# Decimals: 18
# Decimals: 18
# Decimals: 8
# Decimals: 18
# Decimals: 18
# Decimals: 18
# Decimals: 18
# Decimals: 18
# Decimals: 18
# Decimals: 18
# Decimals: 18
# Decimals: 18
# Decimals: 18
# Decimals: 18
# Decimals: 18
# Decimals: 18
# Decimals: 18
# Decimals: 18
# Decimals: 18
# Decimals: 18
# Decimals: 18
# Decimals: 8
# Decimals: 18
# Decimals: 18
# Decimals: 18
# Decimals: 18
# Decimals: 18
# Decimals: 18
# Decimals: 18
# Decimals: 18
# Decimals: 2
# Decimals: 18
# Decimals: 18
# Decimals: 18
# Decimals: 18
# Decimals: 18
# Decimals: 18
# Decimals: 6
# Decimals: 18
# Decimals: 6
# Decimals: 18
# Decimals: 18
# Decimals: 18
# Decimals: 18
# Decimals: 18
# Decimals: 18
# Decimals: 8
# Decimals: 18
# Decimals: 18
# Decimals: 18
# Decimals: 18
# Decimals: 18
# Decimals: 8
# Decimals: 18
# ...

# %%
# Out:
# Empty DataFrame
# Columns: [Decimals]
# Index: []
